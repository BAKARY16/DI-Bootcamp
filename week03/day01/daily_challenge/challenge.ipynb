# %% [markdown]
# **Défi quotidien : Intégration de NumPy, Pandas et Matplotlib**

# %% [markdown]
# Vous êtes analyste de données et travaillez sur un ensemble de données météorologiques mondiales. Votre tâche consiste à analyser les tendances de température et à visualiser les résultats.

# %% [markdown]
# *1. Préparation des données*

# %%
# Importer les bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Générer des données synthétiques pour 10 villes et 12 mois
cities = [f'City {i+1}' for i in range(10)]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Temperatures shape: (10 villes, 12 mois)
temperatures = np.random.uniform(-5, 35, size=(10, 12))
temperatures = np.round(temperatures, 2)
# DataFrame avec villes en index et mois en colonnes
temp_df = pd.DataFrame(temperatures, index=cities, columns=months)
temp_df
# Out:
#            Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# City 1    3.02  17.48  -1.88  21.56  -3.60  21.16   6.47   5.69  17.36  33.10
# City 2   17.50  -0.49  23.09  17.26  22.79  20.36  12.18  13.89  20.03  -1.97
# City 3    8.83  26.36  15.04  12.79  10.64  23.91  11.50  -4.43  10.83  18.51
# City 4   17.72  28.69  -4.53  32.40  13.73   5.73   3.02   8.67  21.58  -3.38
# City 5    8.18  20.20   4.36   3.96  18.47  25.74  33.08  22.57  27.12  31.28
# City 6   17.53  12.97  -0.11  17.78  30.56  25.32  30.16  11.33  10.00  25.50
# City 7   -4.22   4.18  -1.32  23.57   0.32  19.29  34.55  13.76  32.78  22.27
# City 8   20.14   0.32  31.63  32.54  29.25   5.64  24.58  29.00  28.09  -4.10
# City 9    4.79   4.54  -4.91  21.19  27.04   2.40  10.61  19.54  13.99  29.46
# City 10  -3.12  -4.57  22.08  22.56  20.76  11.35  18.23  10.63   3.81  23.09
#
#            Nov    Dec
# City 1   16.04  -4.09
# City 2   13.47   6.59
# City 3    1.61  32.52
# City 4   18.81   5.22
# City 5   14.36  26.60
# City 6   33.97   8.28
# City 7   30.55  -2.40
# City 8   12.95  -4.98
# City 9   17.44  10.91
# City 10   0.72  12.27

# %% [markdown]
# *2. Analyse des données*

# %%
# Calculer la température moyenne annuelle pour chaque ville (moyenne des 12 mois)
city_means = temp_df.mean(axis=1)
print('Température moyenne annuelle par ville :')
print(city_means.round(2))

# Identifier la ville ayant la moyenne la plus élevée et la plus basse
city_max = city_means.idxmax()
city_min = city_means.idxmin()
print()
print(f"Ville avec la température moyenne annuelle la plus élevée : {city_max} ({city_means[city_max]:.2f} °C)")
print(f"Ville avec la température moyenne annuelle la plus basse : {city_min} ({city_means[city_min]:.2f} °C)")
# Out:
# Température moyenne annuelle par ville :
# City 1     11.03
# City 2     13.73
# City 3     14.01
# City 4     12.30
# City 5     19.66
# City 6     18.61
# City 7     14.44
# City 8     17.09
# City 9     13.08
# City 10    11.48
# dtype: float64
#
# Ville avec la température moyenne annuelle la plus élevée : City 5 (19.66 °C)
# Ville avec la température moyenne annuelle la plus basse : City 1 (11.03 °C)

# %%
# Calculer la température moyenne par mois à travers toutes les villes
month_means = temp_df.mean(axis=0)
print()
print('Température moyenne par mois (toutes villes) :')
print(month_means.round(2))
# Out:
# Température moyenne par mois (toutes villes) :
# Jan     9.04
# Feb    10.97
# Mar     8.35
# Apr    20.56
# May    17.00
# Jun    16.09
# Jul    18.44
# Aug    13.06
# Sep    18.56
# Oct    17.38
# Nov    15.99
# Dec     9.09
# dtype: float64

# %% [markdown]
# *3. Visualisation des données*

# %%
# Tracer une courbe pour chaque ville afin de comparer les tendances mensuelles
plt.figure(figsize=(12, 7))
for city in temp_df.index:
    plt.plot(months, temp_df.loc[city], marker='o', label=city)

plt.title('Température Moyenne Mensuelle par Ville')
plt.xlabel('Mois')
plt.ylabel('Température (°C)')
plt.grid(alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Résumé automatique basé sur les calculs ci-dessus
summary = f"La ville avec la température moyenne annuelle la plus élevée est {city_max} ({city_means[city_max]:.2f} °C). La ville avec la température moyenne annuelle la plus basse est {city_min} ({city_means[city_min]:.2f} °C)."
print(summary)
# Out:
# La ville avec la température moyenne annuelle la plus élevée est City 5 (19.66 °C). La ville avec la température moyenne annuelle la plus basse est City 1 (11.03 °C).

# %% [markdown]
# Un bref rapport :
# - **Méthode** : données synthétiques générées avec `np.random.uniform` pour 10 villes et 12 mois.
# - **Analyse** : calculs de la moyenne annuelle par ville (`mean(axis=1)`) et moyenne mensuelle (`mean(axis=0)`).
# - **Visualisation** : une courbe par ville permet de comparer les tendances saisonnières.
# - **Conclusions** : voir la cellule de résumé exécutable pour les villes avec les moyennes annuelles extrêmes.
